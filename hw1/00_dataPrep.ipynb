# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
mkdir -p ./gdrive/MyDrive/CSE498-homework/hw1 && mkdir -p ./gdrive/MyDrive/CSE498-homework/hw1/db && mkdir -p ./gdrive/MyDrive/CSE498-homework/hw1/model && cd ./gdrive/MyDrive/CSE498-homework/hw1

# %%
projPath = './gdrive/MyDrive/CSE498-homework/hw1'

# %%
import torchvision

# %%
saveDir = f'{projPath}/db'
torchvision.datasets.MNIST(saveDir, train=True,  download=True)
torchvision.datasets.MNIST(saveDir, train=False,  download=True)
# Out:
# ...
# Extracting ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw/train-images-idx3-ubyte.gz to ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw
# ...
# Extracting ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw/train-labels-idx1-ubyte.gz to ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw
# ...
# Extracting ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw/t10k-images-idx3-ubyte.gz to ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw
# ...
# Extracting ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./gdrive/MyDrive/CSE498-homework/hw1/db/MNIST/raw
# Processing...
# ...

# %%
torchvision.datasets.CIFAR10(saveDir, train=True, download=True)
torchvision.datasets.CIFAR10(saveDir, train=False, download=True)
# Out:
# ...
# Extracting ./gdrive/MyDrive/CSE498-homework/hw1/db/cifar-10-python.tar.gz to ./gdrive/MyDrive/CSE498-homework/hw1/db
# Files already downloaded and verified
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./gdrive/MyDrive/CSE498-homework/hw1/db
#     Split: Test
